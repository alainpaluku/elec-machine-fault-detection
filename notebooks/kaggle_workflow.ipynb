# %% [markdown]
# # Pipeline de Maintenance Prédictive (TFE)
# Exécutez les cellules ci-dessous pour cloner le projet et générer votre code C.

# %%
# 1. Cloner le dépôt
# !git clone https://github.com/alainpaluku/elec-machine-fault-detection

# 2. Se placer dans le dossier et exécuter le script
# %cd elec-machine-fault-detection
# !bash kaggle_run.sh

# %% [markdown]
# ### Récupération du code C
# Le fichier généré se trouve dans `/kaggle/working/random_forest_rules.c`. Vous pouvez le télécharger via l'onglet 'Output' de Kaggle.
