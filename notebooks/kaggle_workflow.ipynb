# %% [markdown]
# # Pipeline de Maintenance Prédictive (Script Kaggle)
# Ce notebook automatise l'import du code depuis GitHub, l'exécution du modèle, et la génération du code C final pour STM32.

# %%
# 1. Cloner le code de ton projet TFE depuis GitHub
# !git clone https://github.com/Ton_Nom_Utilisateur/Ton_Projet_TFE.git

# %%
# 2. Se placer dans le répertoire du projet
# %cd Ton_Projet_TFE

# Installer les dépendances si nécessaire
# !pip install -r requirements.txt

# %%
# 3. Lancer le pipeline 
# (Le script détectera automatiquement qu'il est sur Kaggle et utilisera les chemins appropriés)
# !python src/main.py

# %%
# 4. Vérifier les premières lignes du code C généré
with open('/kaggle/working/random_forest_rules.c', 'r') as f:
    print("".join(f.readlines()[:30]))
