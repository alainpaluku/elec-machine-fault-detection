# %% [markdown]
# # Pipeline de Maintenance Prédictive (TFE)
# Exécutez la cellule ci-dessous pour cloner le projet et générer votre code C en une seule étape.

# %%
# Remplacez par l'URL de votre dépôt si nécessaire
REPO_URL = "https://github.com/AlainPaluku/Maintenance_Predictive_TFE.git"
REPO_NAME = "Maintenance_Predictive_TFE"

# !git clone {REPO_URL} && cd {REPO_NAME} && bash kaggle_run.sh

# %% [markdown]
# ### Récupération du code C
# Le fichier généré se trouve dans `/kaggle/working/random_forest_rules.c`. Vous pouvez le télécharger via l'onglet 'Output' de Kaggle.
